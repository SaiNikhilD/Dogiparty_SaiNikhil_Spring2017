# %% [markdown]
# # Using Enron data-set, perform **3**  analysis.

# %%
# Importing necessary libraries
import re
import os
import matplotlib.pyplot as plt
import csv
from email.parser import Parser

# %% [markdown]
# Analysis 1 - Number of Emails sent by lay-k Chairman year wise

# %%
mailyearFunction=dict.fromkeys(range(2000,2002),0)
for root, dirs, files in os.walk('maildir/lay-k/_sent'):
        if "sent" in root:
            for file in files:
                with open(os.path.join(root,file),'r',encoding='utf-8',errors='ignore') as e_mail:
                    data=e_mail.read()
                    email=Parser().parsestr(data)
                    year=email["Date"][12:16]
                    year= int(year)
                   
                    if year in mailyearFunction:
                        mailyearFunction[year]+=1

# %%
plt.style.use('ggplot')
plt.style.use('seaborn-notebook')
xaxis=mailyearFunction.keys()
yaxis=mailyearFunction.values()
plt.bar(range(len(mailyearFunction)),yaxis,align='center')
plt.xticks(range(len(mailyearFunction)),xaxis)
plt.ylabel('Frequency of Sent Mails')
plt.xlabel('Year')

plt.show()

# %% [markdown]
# Analysis 2

# %%
# Extracting Email's To list's of Chairman Kenneth Lay for analysis
def sent_email(location):
    
    sent_list = []    

    
    for file in os.listdir(location):
        with open(os.path.join(location, file), 'r',encoding='utf-8') as content_file:
            content = content_file.read()
            
            # To find only sent emails
            sent_list.append(re.findall('[\n\r].*To: \s*([^\n\r]*)', content)[0])
   

    sent_emailids_data = {}
   
    sent_emailids_data['To'] = sent_list
   
    return sent_emailids_data

# Read email from folders to dataframes
dataframe = sent_email('maildir/lay-k/_sent')

# %%
print ('Emails sent to below people by lay-k the Chairman of the company')

sentToList = dataframe['To']

for i in range(len(sentToList)):     # First Example
  
    print   ('To :' +sentToList[i])
   
    print('-------------------------------')
# Out:
# Emails sent to below people by lay-k the Chairman of the company
# To :sherri.reinartz@enron.com
# -------------------------------
# To :lizard_ar@yahoo.com
# -------------------------------
# To :rob.bradley@enron.com
# -------------------------------
# To :michael@optsevents.com
# -------------------------------
# To :jaime.alatorre@enron.com
# -------------------------------
# To :loyal_lay@yahoo.com
# -------------------------------
# To :michael.mann@enron.com
# -------------------------------
# To :michael.mann@enron.com
# -------------------------------
# To :tori.wells@enron.com
# -------------------------------
# To :lizard_ar@yahoo.com
# -------------------------------
# To :ted.enloe@compaq.com
# -------------------------------
# To :lizard_ar@yahoo.com
# -------------------------------
# To :katherine.brown@enron.com
# -------------------------------
# To :mmfoss@uh.edu
# -------------------------------
# To :michael.hicks@enron.com
# -------------------------------
# To :chmoore1@email.msn.com
# -------------------------------
# To :diane.bazelides@enron.com
# -------------------------------
# To :amy.lee@enron.com
# -------------------------------
# To :dyergin@cera.com
# -------------------------------
# To :tori.wells@enron.com, vanessa.groscrand@enron.com, sally.keepers@enron.com
# -------------------------------
# To :darlenet23@earthlink.net
# -------------------------------
# To :chmoore1@email.msn.com
# -------------------------------
# To :joe.hillings@enron.com
# -------------------------------
# To :jeff_hines@hines.com
# -------------------------------
# To :pway@wayholding.com
# -------------------------------
# To :walker@missouri.edu
# -------------------------------
# To :dpeppers@flashfind.com
# -------------------------------
# To :slade_pd@tsu.edu
# -------------------------------
# To :mexicomeeting@weforum.org
# -------------------------------
# To :jeffrey.mcclellan@enron.com
# -------------------------------
# To :georgen@epenergy.com
# -------------------------------
# To :cynthia.sandherr@enron.com
# -------------------------------
# To :rahm@missouri.edu
# -------------------------------
# To :lizard_ar@yahoo.com
# -------------------------------
# To :gil.muhl@enron.com
# -------------------------------
# To :rebekah.rushing@enron.com
# -------------------------------
# To :calvin.eakins@enron.com
# -------------------------------
# To :jeffrey.garten@yale.edu
# -------------------------------
# To :sherri.sera@enron.com
# -------------------------------
# To :joe.hillings@enron.com
# -------------------------------
# To :mtelle@velaw.com
# -------------------------------
# To :katherine.brown@enron.com
# -------------------------------
# To :sherrie@layfam.com, sally.keepers@enron.com
# -------------------------------
# To :skimmel@iexalt.net
# -------------------------------
# To :russell.servat@enron.com
# -------------------------------
# To :jtompkins@iexalt.net
# -------------------------------
# To :mtelle@velaw.com
# -------------------------------
# To :bijangh2000@tavana.net
# -------------------------------
# To :barbette_watts@i2.com
# -------------------------------
# To :bijangh2000@tavana.net
# -------------------------------
# To :mtelle@velaw.com
# -------------------------------
# To :brenda.johnston@enron.com
# -------------------------------
# To :jpickard@softrax.com
# -------------------------------
# To :mmfoss@uh.edu
# -------------------------------
# To :mmfoss@uh.edu
# -------------------------------
# To :richard.amabile@enron.com
# -------------------------------
# To :expense.report@enron.com
# -------------------------------
# To :colin.skellett@enron.com
# -------------------------------
# To :colin.skellett@enron.com
# -------------------------------
# To :lizard_ar@yahoo.com
# -------------------------------
# To :jeffrey.garten@yale.edu
# -------------------------------
# To :valerie.petersen@yale.edu
# -------------------------------
# To :loretta.brelsford@enron.com
# -------------------------------
# To :mayorkatz@ci.portland.or.us
# -------------------------------
# To :gary.fitch@enron.com
# -------------------------------
# To :katherine.brown@enron.com
# -------------------------------
# To :barbara.sain@compaq.com
# -------------------------------
# To :gayla.seiter@enron.com
# -------------------------------
# To :lucie@jhmedia.com
# -------------------------------
# To :creedon@rff.org
# -------------------------------
# To :kitty.colgin@compaq.com
# -------------------------------
# To :ealvittor@yahoo.com
# -------------------------------
# To :ml_research@ml.com
# -------------------------------
# To :buckley@puc.state.pa.us
# -------------------------------
# To :amccarty@houston.org
# -------------------------------
# To :bill_lewis@mckinsey.com
# -------------------------------
# To :william.ramsay@iea.org
# -------------------------------
# To :john.hardy@enron.com
# -------------------------------
# To :shea_dugger@i2.com
# -------------------------------
# To :kevin.hannon@enron.com
# -------------------------------
# To :kelly.merritt@enron.com
# -------------------------------
# To :david.haug@enron.com
# -------------------------------
# To :jimbrulte@aol.com
# -------------------------------
# To :communications@brook.edu
# -------------------------------
# To :maria.mitchell@enron.com
# -------------------------------
# To :anne@vanguardventures.com
# -------------------------------
# To :billy.dorsey@enron.com
# -------------------------------
# To :kapoor@eurasiagroup.net
# -------------------------------
# To :dolores.fisher@enron.com
# -------------------------------
# To :mmilken@knowledgeu.com
# -------------------------------
# To :jeffrey.garten@yale.edu
# -------------------------------
# To :herrold@swbell.net, david@enlineresources.com, beau@layfam.com,
# -------------------------------
# To :tech_786@yahoo.com
# -------------------------------
# To :paulette.brunson@bakerbotts.com
# -------------------------------
# To :news@newsworld.co.uk
# -------------------------------
# To :bennis@txoga.org
# -------------------------------
# To :stelzer@aol.com
# -------------------------------
# To :tom.siekman@compaq.com
# -------------------------------
# To :anabella.sousa@enron.com
# -------------------------------
# To :rebecca.mcdonald@enron.com
# -------------------------------
# To :stelzer@aol.com
# -------------------------------
# To :rightworksmarketing@rightworks.com
# -------------------------------
# To :nicomariscalt@marhnos.com.mx
# -------------------------------
# To :barbara.paige@enron.com
# -------------------------------
# To :jonathan.pershing@iea.org
# -------------------------------
# To :barbara.paige@enron.com
# -------------------------------
# To :shea_dugger@i2.com
# -------------------------------
# To :philippe.bibi@enron.com
# -------------------------------
# To :jeffrey.garten@yale.edu
# -------------------------------
# To :stelzer@aol.com
# -------------------------------
# To :sharon@travelpark.com
# -------------------------------
# To :nicholap@asiasoc.org
# -------------------------------
# To :billy.dorsey@enron.com
# -------------------------------
# To :jsikes@cfr.org
# -------------------------------
# To :lists@nbr.org
# -------------------------------
# To :the.globalist@enron.com
# -------------------------------
# To :lindaeb@westcoal.org
# -------------------------------
# To :robert_pondiscio@businessweek.com
# -------------------------------
# To :dmitry@worldrg.com
# -------------------------------
# To :richardnolan@smipublishing.co.uk
# -------------------------------
# To :derek@ctaonline.com
# -------------------------------
# To :rebecca.mcdonald@enron.com
# -------------------------------
# To :theodore.a.schwab@rssmb.com
# -------------------------------
# To :jjankows@kcc.com
# -------------------------------
# To :ehvaughan@vnsm.com
# -------------------------------
# To :aculver@houston.org
# -------------------------------
# To :alliancetosaveenergy@ase.org
# -------------------------------
# To :ohi_supporters@operationhope.org
# -------------------------------
# To :aculver@houston.org
# -------------------------------
# To :amccarty@houston.org
# -------------------------------
# To :dave.kapavik@verizon.com
# -------------------------------
# To :lisa.assaf@enron.com
# -------------------------------
# To :mkg1@pdq.net
# -------------------------------
# To :will.reed@techforall.org
# -------------------------------
# To :eric.thode@enron.com
# -------------------------------
# To :j_hoelscher@hotmail.com
# -------------------------------
# To :shea_dugger@i2.com
# -------------------------------
# To :daggett@heinzctr.org
# -------------------------------
# To :mkaplan@carbon.cudenver.edu
# -------------------------------
# To :bryce@juno.com
# -------------------------------
# To :info@byobroadcast.00b.net
# -------------------------------
# To :shea_dugger@i2.com
# -------------------------------
# To :jcostamagna@evolve.com
# -------------------------------
# To :expense.report@enron.com
# -------------------------------
# To :barbara.sain@compaq.com
# -------------------------------
# To :terrie.james@enron.com
# -------------------------------
# To :terrie.james@enron.com
# -------------------------------
# To :barbara.sain@compaq.com
# -------------------------------
# To :barbara.sain@compaq.com
# -------------------------------
# To :sheila@ctaonline.com
# -------------------------------
# To :jeffrey.garten@yale.edu
# -------------------------------
# To :jonathan.pershing@iea.org
# -------------------------------
# To :simone.rose@enron.com
# -------------------------------
# To :wanda.holloway@compaq.com
# -------------------------------
# To :joe.hillings@enron.com, cynthia.sandherr@enron.com, steven.kean@enron.com
# -------------------------------
# To :beau@layfam.com
# -------------------------------
# To :mschopper@houston.org
# -------------------------------
# To :sostrow@bayou.uh.edu
# -------------------------------
# To :eva_evgenis@acml.com
# -------------------------------
# To :mhk@heinzctr.org
# -------------------------------
# To :tim.despain@enron.com
# -------------------------------
# To :outlook.team@enron.com
# -------------------------------
# To :jean.ryall@enron.com
# -------------------------------
# To :indiasummit@weforum.org
# -------------------------------
# To :john.lavorato@enron.com
# -------------------------------
# To :sherri.sera@enron.com
# -------------------------------
# To :mike.mcconnell@enron.com
# -------------------------------
# To :rhaynes@poloralphlauren.com
# -------------------------------
# To :sjhoil@earthlink.com
# -------------------------------
# To :jonathan.pershing@iea.org
# -------------------------------
# To :ken.rice@enron.com
# -------------------------------
# To :lance.schuler-legal@enron.com
# -------------------------------
# To :tonda_bunge@yahoo.com
# -------------------------------
# To :hvg@carbon.cudenver.edu
# -------------------------------
# To :aervin@houston.org
# -------------------------------
# To :gabriella.goekjian@oecd.org
# -------------------------------
# To :sherri.sera@enron.com
# -------------------------------
# To :jonathan.pershing@iea.org
# -------------------------------
# To :robert_donohoo@i2.com
# -------------------------------
# To :swhalen@calstate.edu
# -------------------------------
# To :swhalen@calstate.edu
# -------------------------------
# To :expense.report@enron.com
# -------------------------------
# To :terry_pierce@enron.net
# -------------------------------
# To :gary.fitch@enron.com
# -------------------------------
# To :cmkrishna@bangaloreit.com
# -------------------------------
# To :jmathews@jefferson-usa.com
# -------------------------------
# To :tnktaylor@earthlink.net
# -------------------------------
# To :lizard_ar@yahoo.com
# -------------------------------
# To :lindaeb@westcoal.org
# -------------------------------
# To :joe.hillings@enron.com, cynthia.sandherr@enron.com, chris.long@enron.com,
# -------------------------------
# To :jeffrey.garten@yale.edu
# -------------------------------
# To :ajones@uwtgc.org
# -------------------------------
# To :sharon.lay@travelpark.com
# -------------------------------
# To :sunb9902b@ccsurvey.com
# -------------------------------
# To :expense.report@enron.com
# -------------------------------
# To :hitoshi.misaki@toshiba.co.jp
# -------------------------------
# To :jeffrey.mcclellan@enron.com
# -------------------------------
# To :richard.leibert@enron.com
# -------------------------------
# To :skimmel@iexalt.net
# -------------------------------
# To :epi@steps-peace.org
# -------------------------------
# To :ksaucier@hobbycomm.com
# -------------------------------
# To :nsexton@clubforgrowth.org
# -------------------------------
# To :sally.keepers@enron.com
# -------------------------------
# To :pramath_sinha@isbindia.org
# -------------------------------
# To :rob.bradley@enron.com
# -------------------------------
# To :jeffrey.mcclellan@enron.com
# -------------------------------
# To :sanjay.bhatnagar@enron.com
# -------------------------------
# To :contact@weforum.org
# -------------------------------
# To :maryse_zwick@weforum.org
# -------------------------------
# To :helpdesk@mailman.enron.com
# -------------------------------
# To :lisa.l.brown@us.pwcglobal.com
# -------------------------------
# To :skimmel@iexalt.net
# -------------------------------
# To :jkollaer@houston.org
# -------------------------------
# To :jfierro@barter.com
# -------------------------------
# To :ted.enloe@compaq.com
# -------------------------------
# To :expense.report@enron.com
# -------------------------------
# To :mbartley@asiasoc.org
# -------------------------------
# To :service@sbsubscriber.com
# -------------------------------
# To :jeffrey.garten@yale.edu
# -------------------------------
# To :mizzouwally@compuserve.com
# -------------------------------
# To :jerusalemfund@aol.com
# -------------------------------
# To :expense.report@enron.com
# -------------------------------
# To :richarde@centurydev.com
# -------------------------------
# To :kent.grusendorf@gte.net
# -------------------------------
# To :jeffrey.garten@yale.edu
# -------------------------------
# To :dhulton@euromoneypic.com
# -------------------------------
# To :maxwells@train.missouri.org
# -------------------------------
# To :godwin.carmona@aspeninstitute.org
# -------------------------------
# To :lizard_ar@yahoo.com
# -------------------------------
# To :kathy.mayfield@enron.com, sherri.sera@enron.com, pam.benson@enron.com,
# -------------------------------
# To :redherring-61399@mailsubs.com
# -------------------------------
# To :djbryant@insync.net
# -------------------------------
# To :katherine.brown@enron.com
# -------------------------------
# To :mrslinda@lplpi.com
# -------------------------------
# To :godwin.carmona@aspeninstitute.org
# -------------------------------
# To :lizard_ar@yahoo.com
# -------------------------------
# To :mgriffes@evelocity.com
# -------------------------------
# To :skimmel@iexalt.net
# -------------------------------
# To :hanley@risk.co.uk
# -------------------------------
# To :lizard_ar@yahoo.com
# -------------------------------
# To :src@delphigroup.com
# -------------------------------
# To :katherine.brown@enron.com
# -------------------------------
# To :sarah.davis@enron.com
# -------------------------------
# To :ceoextra@houston.org
# -------------------------------
# To :lizard_ar@yahoo.com
# -------------------------------
# To :timmy.ng@enron.com
# -------------------------------
# To :don.black@enron.com
# -------------------------------
# To :dpeppers@flashfind.com
# -------------------------------
# To :walterpye@email.msn.com
# -------------------------------
# To :katherine.brown@enron.com
# -------------------------------
# To :dstraszheim@milken-inst.org
# -------------------------------
# To :sherrie@layfam.com, sally.keepers@enron.com
# -------------------------------
# To :sherrie@layfam.com
# -------------------------------
# To :debbie.nowak@enron.com
# -------------------------------
# To :katherine.brown@enron.com
# -------------------------------
# To :galvan666@aol.com
# -------------------------------
# To :bgrady@carlylesf.com
# -------------------------------
# To :jwatson@velaw.com
# -------------------------------
# To :johnp@energycoaliton.org
# -------------------------------
# To :gene.humphrey@enron.com
# -------------------------------
# To :rob.bradley@enron.com
# -------------------------------

# %%
#Finding the frequency of emails
def freq_emails(mails):
    freq = {}
    for mail in mails:
        if mail not in freq:
            freq[mail] = 1
        else:
            freq[mail] += 1
    return freq

# %%
#Getting freqency of mail id's using freq_emails function
enron_chairamn_freq = freq_emails(sentToList)

#Sorting the emails with count in descending order
sortedlist = sorted(enron_chairamn_freq.items(), key = lambda x:x[1], reverse = True)
sortedlist
# Out:
# [('lizard_ar@yahoo.com', 10),
#  ('jeffrey.garten@yale.edu', 8),
#  ('katherine.brown@enron.com', 7),
#  ('expense.report@enron.com', 6),
#  ('skimmel@iexalt.net', 4),
#  ('barbara.sain@compaq.com', 4),
#  ('shea_dugger@i2.com', 4),
#  ('jonathan.pershing@iea.org', 4),
#  ('rob.bradley@enron.com', 3),
#  ('mmfoss@uh.edu', 3),
#  ('jeffrey.mcclellan@enron.com', 3),
#  ('sherri.sera@enron.com', 3),
#  ('mtelle@velaw.com', 3),
#  ('stelzer@aol.com', 3),
#  ('michael.mann@enron.com', 2),
#  ('ted.enloe@compaq.com', 2),
#  ('chmoore1@email.msn.com', 2),
#  ('joe.hillings@enron.com', 2),
#  ('dpeppers@flashfind.com', 2),
#  ('sherrie@layfam.com, sally.keepers@enron.com', 2),
#  ('bijangh2000@tavana.net', 2),
#  ('colin.skellett@enron.com', 2),
#  ('gary.fitch@enron.com', 2),
#  ('amccarty@houston.org', 2),
#  ('billy.dorsey@enron.com', 2),
#  ('rebecca.mcdonald@enron.com', 2),
#  ('barbara.paige@enron.com', 2),
#  ('lindaeb@westcoal.org', 2),
#  ('aculver@houston.org', 2),
#  ('terrie.james@enron.com', 2),
#  ('swhalen@calstate.edu', 2),
#  ('godwin.carmona@aspeninstitute.org', 2),
#  ('sherri.reinartz@enron.com', 1),
#  ('michael@optsevents.com', 1),
#  ('jaime.alatorre@enron.com', 1),
#  ('loyal_lay@yahoo.com', 1),
#  ('tori.wells@enron.com', 1),
#  ('michael.hicks@enron.com', 1),
#  ('diane.bazelides@enron.com', 1),
#  ('amy.lee@enron.com', 1),
#  ('dyergin@cera.com', 1),
#  ('tori.wells@enron.com, vanessa.groscrand@enron.com, sally.keepers@enron.com',
#   1),
#  ('darlenet23@earthlink.net', 1),
#  ('jeff_hines@hines.com', 1),
#  ('pway@wayholding.com', 1),
#  ('walker@missouri.edu', 1),
#  ('slade_pd@tsu.edu', 1),
#  ('mexicomeeting@weforum.org', 1),
#  ('georgen@epenergy.com', 1),
#  ('cynthia.sandherr@enron.com', 1),
#  ('rahm@missouri.edu', 1),
#  ('gil.muhl@enron.com', 1),
#  ('rebekah.rushing@enron.com', 1),
#  ('calvin.eakins@enron.com', 1),
#  ('russell.servat@enron.com', 1),
#  ('jtompkins@iexalt.net', 1),
#  ('barbette_watts@i2.com', 1),
#  ('brenda.johnston@enron.com', 1),
#  ('jpickard@softrax.com', 1),
#  ('richard.amabile@enron.com', 1),
#  ('valerie.petersen@yale.edu', 1),
#  ('loretta.brelsford@enron.com', 1),
#  ('mayorkatz@ci.portland.or.us', 1),
#  ('gayla.seiter@enron.com', 1),
#  ('lucie@jhmedia.com', 1),
#  ('creedon@rff.org', 1),
#  ('kitty.colgin@compaq.com', 1),
#  ('ealvittor@yahoo.com', 1),
#  ('ml_research@ml.com', 1),
#  ('buckley@puc.state.pa.us', 1),
#  ('bill_lewis@mckinsey.com', 1),
#  ('william.ramsay@iea.org', 1),
#  ('john.hardy@enron.com', 1),
#  ('kevin.hannon@enron.com', 1),
#  ('kelly.merritt@enron.com', 1),
#  ('david.haug@enron.com', 1),
#  ('jimbrulte@aol.com', 1),
#  ('communications@brook.edu', 1),
#  ('maria.mitchell@enron.com', 1),
#  ('anne@vanguardventures.com', 1),
#  ('kapoor@eurasiagroup.net', 1),
#  ('dolores.fisher@enron.com', 1),
#  ('mmilken@knowledgeu.com', 1),
#  ('herrold@swbell.net, david@enlineresources.com, beau@layfam.com, ', 1),
#  ('tech_786@yahoo.com', 1),
#  ('paulette.brunson@bakerbotts.com', 1),
#  ('news@newsworld.co.uk', 1),
#  ('bennis@txoga.org', 1),
#  ('tom.siekman@compaq.com', 1),
#  ('anabella.sousa@enron.com', 1),
#  ('rightworksmarketing@rightworks.com', 1),
#  ('nicomariscalt@marhnos.com.mx', 1),
#  ('philippe.bibi@enron.com', 1),
#  ('sharon@travelpark.com', 1),
#  ('nicholap@asiasoc.org', 1),
#  ('jsikes@cfr.org', 1),
#  ('lists@nbr.org', 1),
#  ('the.globalist@enron.com', 1),
#  ('robert_pondiscio@businessweek.com', 1),
#  ('dmitry@worldrg.com', 1),
#  ('richardnolan@smipublishing.co.uk', 1),
#  ('derek@ctaonline.com', 1),
#  ('theodore.a.schwab@rssmb.com', 1),
#  ('jjankows@kcc.com', 1),
#  ('ehvaughan@vnsm.com', 1),
#  ('alliancetosaveenergy@ase.org', 1),
#  ('ohi_supporters@operationhope.org', 1),
#  ('dave.kapavik@verizon.com', 1),
#  ('lisa.assaf@enron.com', 1),
#  ('mkg1@pdq.net', 1),
#  ('will.reed@techforall.org', 1),
#  ('eric.thode@enron.com', 1),
#  ('j_hoelscher@hotmail.com', 1),
#  ('daggett@heinzctr.org', 1),
#  ('mkaplan@carbon.cudenver.edu', 1),
#  ('bryce@juno.com', 1),
#  ('info@byobroadcast.00b.net', 1),
#  ('jcostamagna@evolve.com', 1),
#  ('sheila@ctaonline.com', 1),
#  ('simone.rose@enron.com', 1),
#  ('wanda.holloway@compaq.com', 1),
#  ('joe.hillings@enron.com, cynthia.sandherr@enron.com, steven.kean@enron.com',
#   1),
#  ('beau@layfam.com', 1),
#  ('mschopper@houston.org', 1),
#  ('sostrow@bayou.uh.edu', 1),
#  ('eva_evgenis@acml.com', 1),
#  ('mhk@heinzctr.org', 1),
#  ('tim.despain@enron.com', 1),
#  ('outlook.team@enron.com', 1),
#  ('jean.ryall@enron.com', 1),
#  ('indiasummit@weforum.org', 1),
#  ('john.lavorato@enron.com', 1),
#  ('mike.mcconnell@enron.com', 1),
#  ('rhaynes@poloralphlauren.com', 1),
#  ('sjhoil@earthlink.com', 1),
#  ('ken.rice@enron.com', 1),
#  ('lance.schuler-legal@enron.com', 1),
#  ('tonda_bunge@yahoo.com', 1),
#  ('hvg@carbon.cudenver.edu', 1),
#  ('aervin@houston.org', 1),
#  ('gabriella.goekjian@oecd.org', 1),
#  ('robert_donohoo@i2.com', 1),
#  ('terry_pierce@enron.net', 1),
#  ('cmkrishna@bangaloreit.com', 1),
#  ('jmathews@jefferson-usa.com', 1),
#  ('tnktaylor@earthlink.net', 1),
#  ('joe.hillings@enron.com, cynthia.sandherr@enron.com, chris.long@enron.com, ',
#   1),
#  ('ajones@uwtgc.org', 1),
#  ('sharon.lay@travelpark.com', 1),
#  ('sunb9902b@ccsurvey.com', 1),
#  ('hitoshi.misaki@toshiba.co.jp', 1),
#  ('richard.leibert@enron.com', 1),
#  ('epi@steps-peace.org', 1),
#  ('ksaucier@hobbycomm.com', 1),
#  ('nsexton@clubforgrowth.org', 1),
#  ('sally.keepers@enron.com', 1),
#  ('pramath_sinha@isbindia.org', 1),
#  ('sanjay.bhatnagar@enron.com', 1),
#  ('contact@weforum.org', 1),
#  ('maryse_zwick@weforum.org', 1),
#  ('helpdesk@mailman.enron.com', 1),
#  ('lisa.l.brown@us.pwcglobal.com', 1),
#  ('jkollaer@houston.org', 1),
#  ('jfierro@barter.com', 1),
#  ('mbartley@asiasoc.org', 1),
#  ('service@sbsubscriber.com', 1),
#  ('mizzouwally@compuserve.com', 1),
#  ('jerusalemfund@aol.com', 1),
#  ('richarde@centurydev.com', 1),
#  ('kent.grusendorf@gte.net', 1),
#  ('dhulton@euromoneypic.com', 1),
#  ('maxwells@train.missouri.org', 1),
#  ('kathy.mayfield@enron.com, sherri.sera@enron.com, pam.benson@enron.com, ',
#   1),
#  ('redherring-61399@mailsubs.com', 1),
#  ('djbryant@insync.net', 1),
#  ('mrslinda@lplpi.com', 1),
#  ('mgriffes@evelocity.com', 1),
#  ('hanley@risk.co.uk', 1),
#  ('src@delphigroup.com', 1),
#  ('sarah.davis@enron.com', 1),
#  ('ceoextra@houston.org', 1),
#  ('timmy.ng@enron.com', 1),
#  ('don.black@enron.com', 1),
#  ('walterpye@email.msn.com', 1),
#  ('dstraszheim@milken-inst.org', 1),
#  ('sherrie@layfam.com', 1),
#  ('debbie.nowak@enron.com', 1),
#  ('galvan666@aol.com', 1),
#  ('bgrady@carlylesf.com', 1),
#  ('jwatson@velaw.com', 1),
#  ('johnp@energycoaliton.org', 1),
#  ('gene.humphrey@enron.com', 1)]

# %% [markdown]
# Storing the data in csv

# %%
with open('Enron_sentmail_layk_freq.csv', 'w', newline="") as csvfile:
    csv_output = csv.writer(csvfile)
    csv_output.writerow(['Mail Ids', 'Frequency'])
    for row in sortedlist:
        csv_output.writerow([row[0], row[1]])
        csvfile.close

# %% [markdown]
# Analysis 3 - To check which hour has he sent the most mails

# %%
hourFunction=dict.fromkeys(range(1,25),0)
for root, dirs, files in os.walk('maildir/lay-k/_sent'):
        if "sent" in root:
            for f in files:
                with open(os.path.join(root,f),'r',encoding='utf-8',errors='ignore') as e:
                    data=e.read()
                    email=Parser().parsestr(data)
                    hour=email["Date"][16:18]
                    hour= int(hour)
                   
                    if hour in hourFunction:
                        hourFunction[hour]+=1

# %%
plt.style.use('ggplot')
plt.style.use('seaborn-notebook')
x=hourFunction.keys()
y=hourFunction.values()
plt.bar(range(len(hourFunction)),y,align='center')
plt.xticks(range(len(hourFunction)),x)
plt.ylabel('Frequency of Sent Mails ')
plt.xlabel('Hours of the Day')

plt.show()

# %% [markdown]
# Analysis has been written in a seperate "readme" file
